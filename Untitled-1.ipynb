# %%
import numpy as np

# %%
num = np.array([11,22,33,44,55])
newsear = np.where(num == 33)
print(newsear)
# Out:
# (array([2]),)

# %%
import numpy as np

arr = np.array([6, 7, 8, 9])

x = np.searchsorted(arr, 7)

print(x)
# Out:
# 1

# %%
arr = np.array([10, 20, 30, 40, 50, 30, 60])
newsear = np.where(arr == 30)
print(newsear)
# Out:
# (array([2, 5]),)
